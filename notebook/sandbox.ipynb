# %%
import numpy as np
import pandas as pd
import csv
import copy
import re
from collections import Counter

from sklearn.utils import shuffle
from keras.models import Model
from keras.layers import Input, LSTM, Dense, Embedding, Bidirectional, Flatten, concatenate, multiply
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling2D
# Out:
# Using TensorFlow backend.

# %%
class Path():
    train_file_path = "../data/train_stories.csv"
    val_file_path = "../data/val_stories.csv"

# %%
class Data(Path):
    def __init__(self):
        self.most_common   = 2
        self.max_seqlen    = 30
        self.prepare_dummy = True
        
        self.unk = "<UNK>"
        self.bos = "<BOS>"
        self.eos = "<EOS>"
        self.pad = "<PAD>"
        
        self.train_dataset, self.y = self.load_train_text(Path.train_file_path)
        self.vocab                 = self.create_vocab() # used in test
        self.w2i_dict              = self.create_w2i_dict() # used in test
        self.i2w_dict              = self.create_i2w_dict() # used in test
        self.train_dataset_ids     = self.convert_w2i_dataset(self.train_dataset) 
        self.train_x               = self.train_dataset_ids
        
        self.test_dataset,         self.answers = self.load_test_text(Path.val_file_path)
        self.test_dataset_ids                   = self.convert_w2i_dataset(self.test_dataset)
        self.test_x, self.test_e1, self.test_e2 = self.split_test_dataset(self.test_dataset_ids)
        
        # report about variables
        print('''
        ==================================================
        words with frequency less than {} is not in vocab.
        maximum sentencelength: {}
        train_x.shape:  {}
        test_x.shape:   {}
        test_e1.shape:  {}
        test_e2.shape:  {}
        len(vocab):     {}
        ==================================================
        '''.format(self.most_common, self.max_seqlen, self.train_x.shape,
                  self.test_x.shape, self.test_e1.shape, self.test_e2.shape, len(self.vocab)))
        
    def split_test_dataset(self, dataset):
        # assuming dataset.shape = (datanum, 4 + 1 + 1, 30)
        # TODO: remove hardcoding
        return dataset[:, :4, :], dataset[:, 4:5, :], dataset[:, 5:, :]
        
    def clean_text(self, string):
        string = string.lower()

        # insert space before special symbols
        string = re.sub("(['.,!?])", r' \g<1>', string)

        return string

    def load_test_text(self, datapath):
        df = pd.read_csv(datapath)

        story_ids = df['InputStoryid'].tolist()
        stories = (df[['InputSentence1', 'InputSentence2', 'InputSentence3', 'InputSentence4', 
                       'RandomFifthSentenceQuiz1', 'RandomFifthSentenceQuiz2']])
        answers = df['AnswerRightEnding'].tolist()
        
        lines = stories.values.tolist()
        if self.max_seqlen:
            lines = ([[[self.bos] + clean_text(string).split() + [self.eos]
                       + [self.pad] * (self.max_seqlen - len(clean_text(string).split()) - 2)
                      for string in line] for line in lines])
        
        self.test_story_ids = story_ids
        return lines, answers
        
    def augment_with_fake(self, df):
        """
        Given df, this function copies it and replace 'sentence5' with fake ending
        (picked from each of 'sentence1'-'sentence4' in the same row), appending new df to old df.
        so the dataset will be 5 times bigger.
        """
        augmented_df = copy.copy(df)
        augmented_answers = np.ones(len(df))
        
        for column_name in ['sentence1', 'sentence2', 'sentence3', 'sentence4']:
            fake_df = copy.copy(df)
            fake_answers = np.zeros(len(fake_df))
            
            fake_df['sentence5'] = df[column_name]
            augmented_df = augmented_df.append(fake_df, ignore_index=True)
            augmented_answers = np.concatenate((augmented_answers, fake_answers), axis=0)

        assert len(augmented_df) == len(augmented_answers)
        
        return augmented_df, augmented_answers
        
    def load_train_text(self, datapath):

        df = pd.read_csv(datapath)
        story_ids = df['storyid'].tolist()
        story_titles = df['storytitle']# extract only 'title'
        stories = df[['sentence1', 'sentence2', 'sentence3', 'sentence4', 'sentence5']]
        # stories_with_fake_ending = copy.copy(stories)
        # append "fake sentence" column to stories
        answers = np.ones(len(stories))
        
        if self.prepare_dummy:
            stories, answers = self.augment_with_fake(stories)
        
        lines = stories.values.tolist() 
        if self.max_seqlen:
            lines = ([[[self.bos] + clean_text(string).split() + [self.eos] 
                       + [self.pad] * (self.max_seqlen - len(clean_text(string).split()) - 2)
                       for string in line] for line in lines]) # extract 'sentence1 - 5'
        else:
            lines = [[clean_text(string).split() for string in line[2:]] for line in lines]
            
        self.train_story_ids = story_ids
        self.train_story_titles = story_titles
        return lines, answers

    def create_vocab(self):
        flattened_dataset = [word for sentences in self.train_dataset for sentence in sentences[1:] for word in sentence]
        vocab = dict(Counter(flattened_dataset), most_common=self.most_common)
        vocab[self.unk] = 1
        return vocab
    
    def create_w2i_dict(self):
        """
        vocab which converts word to id
        """
        w2i_vocab = dict()
        w2i_vocab[self.pad] = 0
        i = 1
        for key, val in self.vocab.items():
            if w2i_vocab.get(key) == None:
                w2i_vocab[key] = i
                i += 1            
                
        return w2i_vocab
    
    def create_i2w_dict(self):
        return {v: k for k, v in self.w2i_dict.items()}
    
    def get_id(self, word):
        ind = self.w2i_dict.get(word)
        if ind == None:
            return self.w2i_dict[self.unk]
        return ind
    
    def convert_w2i_dataset(self, dataset):
        array = np.array([[[self.get_id(word) for word in sentence] for sentence in sentences] for sentences in dataset])
        return array

    def convert_i2w_dataset(self):
        pass
    
    def prepare_training_data(self):
        train_x, train_y = self.dataset_ids[:, :4, :], self.dataset_ids[:, 4:, :]
        return train_x, train_y

    def depth(l):
        """
        get the depth of the list (unused for now)
        """
        if isinstance(l, list):
            return 1 + max(depth(item) for item in l)
        else:
            return 0
        
    # TODO is test data converted to ids correctly?

# %%
data = Data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-330cae829484> in <module>()
# ----> 1 data = Data()
#
# NameError: name 'Data' is not defined

# %%
df = pd.read_csv(Path.train_file_path)

# %%
max([len(sentence.split()) for sentence in df['sentence5'].tolist()])
# Out:
# 19

# %%
df['sentence1'].tolist()[0].split()
# Out:
# ['Kelly',
#  'found',
#  'her',
#  "grandmother's",
#  'pizza',
#  'recipe',
#  'in',
#  'a',
#  'shoebox',
#  'of',
#  'memories.']

# %%
class Seq2Seq():
    """
    ref: https://blog.keras.io/a-ten-minute-introduction-to-sequence-to-sequence-learning-in-keras.html
    """
    def __init__(self):
        self.embed_dim = 128
        self.hidden_dim = 64
        self.batchsize = 64
        self.epochs = 10
    
    def __call__(self, x, y):
        # seq2seq model.
        encoder_inputs = Input(shape=(None, 30))
        decoder_inputs = Input(shape=(None, 30))

        encoder = LSTM(self.hidden_dim, return_state=True)
        embeddings = Embedding(input_dim=len(data.vocab), output_dim=self.embed_dim,
                               input_length=data.max_seqlen, mask_zero=True)
        decoder = LSTM(self.hidden_dim, return_state=True)
        decoder_fc = Dense(len(data.vocab), activation='softmax')

        # start encoding.
        x = embeddings(encoder_inputs) # [batchsize, 30] -> [batchsize, 30, output_dim]
        encoder_outputs, state_h, state_c = encoder(x) # state: [batchsize, hidden_dim]
        encoder_states = [state_h, state_c]

        # start decoding, using `encoder_states` as initial state.
        decoder_embeddings =embeddings(decoder_inputs)
        decoder_outputs, _, _ = decoder(decoder_embeddings, initial_state = encoder_states)
        decoder_target = decoder_fc(decoder_outputs)
        
        model = Model([encoder_inputs, decoder_inputs], decoder_target)
        
        model.compile(optimizer='sgd', loss='categorical_crossentropy')
        model.fit([x, y], y[:, 1:, :],
                  batch_size=batch_size,
                  epochs=epochs,
                  validation_split=0.2)
        # decoder_target must be ahead by 1.

# %%
class Classifier():
    def __init__(self):
        self.embed_dim = 128
        self.hidden_dim = 64
        self.feature_dim = 32
        self.model = None
        self.batchsize = 64
        self.epochs = 1

        self.n_stories = 4
        self.n_options = 1
        
    def build_model(self):
        story_inputs = [Input(shape=(data.max_seqlen,)) for _ in range(self.n_stories)]
        option_inputs = [Input(shape=(data.max_seqlen,)) for _ in range(self.n_options)]
        # TODO; prepare and input dummy sentence
        
        inputs = story_inputs + option_inputs
        embed_layer = Embedding(input_dim=len(data.vocab), output_dim=self.embed_dim,
                               input_length=data.max_seqlen, mask_zero=True)
        birnn_layer = Bidirectional(LSTM(self.hidden_dim))
        dense_layer = Dense(self.feature_dim, activation='relu')
        ending_dense_layer = Dense(self.n_stories * self.feature_dim, activation='relu')

        embeddings = [embed_layer(_input) for _input in inputs]
        birnn_outputs = [birnn_layer(embedding) for embedding in embeddings]
        fc_outputs = [dense_layer(birnn_output) for birnn_output in birnn_outputs[:self.n_stories]]
        ending_features = ending_dense_layer(birnn_outputs[4])
        
        story_features = concatenate(fc_outputs)
        story_features = multiply([story_features, ending_features]) # TODO make it more exact like paper do
#         conv = Conv1D(16, kernel_size=3, activation='relu')(story_features)
        fc = Dense(1, activation='sigmoid')(story_features)
        model = Model(inputs=inputs, outputs=fc)
        model.compile(optimizer='sgd', loss = 'binary_crossentropy')
        self.model = model
    
    def train(self, inputs, outputs):
        if self.model == None:
            raise ValueError("self.model is None. run build_model() first.")
        self.model.fit(inputs, outputs, epochs=self.epochs, batch_size=self.batchsize) 
    
    def test(self, inputs, batchsize):
        if self.model == None:
            raise ValueError("self.model is None. run build_model() first.")
        prediction = self.model.predict(inputs, batchsize=batchsize)
        return prediction

# %%
classifier = Classifier()

# %%
classifier.build_model()

# %%
inputs = [data.train_x[:, i, :] for i in range(5)]
answers = data.y
classifier.train(inputs, answers)
# Out:
# Epoch 1/1
#  65536/440805 [===>..........................] - ETA: 51:06 - loss: 0.5308

# %%
df = pd.read_csv("../data/storydata_all.csv")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# <ipython-input-3-614efdd70cd9> in <module>()
# ----> 1 df = pd.read_csv("../data/storydata_all.csv")
#
# /Users/tong/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# /Users/tong/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     399         return parser
#     400
# --> 401     data = parser.read()
#     402     parser.close()
#     403     return data
#
# /Users/tong/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#     937                 raise ValueError('skipfooter not supported for iteration')
#     938
# --> 939         ret = self._engine.read(nrows)
#     940
#     941         if self.options.get('as_recarray'):
#
# /Users/tong/.pyenv/versions/anaconda3-4.3.1/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1506     def read(self, nrows=None):
#    1507         try:
# -> 1508             data = self._reader.read(nrows)
#    1509         except StopIteration:
#    1510             if self._first_chunk:
#
# pandas/parser.pyx in pandas.parser.TextReader.read (pandas/parser.c:10415)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_low_memory (pandas/parser.c:10691)()
#
# pandas/parser.pyx in pandas.parser.TextReader._read_rows (pandas/parser.c:11437)()
#
# pandas/parser.pyx in pandas.parser.TextReader._tokenize_rows (pandas/parser.c:11308)()
#
# pandas/parser.pyx in pandas.parser.raise_parser_error (pandas/parser.c:27037)()
#
# CParserError: Error tokenizing data. C error: Expected 6 fields in line 14, saw 7

# %%
df = pd.read_csv('../data/ROCStories__spring2016 - ROCStories_spring2016.csv')

# %%
df
# Out:
#                                     storyid                 storytitle  \
# 0      9a51198e-96f1-42c3-b09d-a3e1e067d803             Overweight Kid
# 1      617e7ada-3878-488d-bd56-40695b91f053          The Bike Accident
# 2      79b0da1f-e460-4173-ba58-8c9e2553c53a                      Beach
# 3      d173b7de-4611-4cdf-934c-912834755e41          The bad customer.
# 4      af0fd5a4-de36-47ba-8aa2-e99d10986d7a              Being Patient
# 5      5d5e7aeb-332f-4c8b-a3c3-44585501e493              Foolish Frank
# 6      bdceebb0-c6e8-417f-b6ae-741a0a71fcd3            Shark Adventure
# 7      a4a9aaca-d3d4-46b4-807c-ef75aea68c56        Too sunny for Sunny
# 8      8ddc9d26-d253-4eb3-b621-9a4e6d9c57e0            The Merry Widow
# 9      80ff5d8f-bcb1-437b-9da1-71c52997def2                 Golf Cheat
# 10     f205679f-a512-4c69-8c70-4c5d081bc162                Josh's Bird
# 11     e88711d0-3e7e-4b6f-a36e-d4dce15969f4                      Leash
# 12     2ba826c3-4b57-42fa-9784-8fc5c8f954ac    She Is The Saddest Girl
# 13     19d9e1e4-6d82-44c8-9c74-3a5e866b2e6d             Being Creative
# 14     e95f0861-813b-4801-b2a5-74733aef86db                    Company
# 15     a15c9a13-e251-4461-b74d-e6549c6633a7                       Chat
# 16     a09017e9-0d29-46d6-8078-4ba2853d361c             Lottery Winner
# 17     25dfd390-d56a-4dca-82bd-508c6ba6116d      Not Quite A Fairytale
# 18     0a9e9018-c1dc-485d-adbe-c1e18f5e022f           Board game night
# 19     dc5f5981-b1c5-47da-87f6-0dfba31c99d3               Screen Porch
# 20     a2621836-f242-40dc-8460-a1ab86ba59c6                  The Beach
# 21     3097473f-8b80-4521-b8aa-d13f6f4049f3                        Pet
# 22     58baa0f3-14ef-42a8-84a9-773fac0978ee             Hotdog contest
# 23     6aedadf7-2ed1-4883-a0c8-057c39d830fd                    Youtube
# 24     daed2b60-8579-4de5-b608-c8bdd1529692                Jeff moving
# 25     3e53cf10-5e80-41d2-b7bb-fc910480a1be               Broken ankle
# 28     His wife thought it was hideous and clashed wi...
# 29     She thought she could go out to the deeper end...
# ...                                                  ...
# 45466                   A car passed him really quickly.
# 45467              They were her favorite kind of candy.
# 45468  She cried as she she informed the officer didn...
# 45469                 Today he hoped to hit the jackpot.
# 45470         My brother got me tickets for my birthday.
# 45471             He had just arrived in northern Spain.
# 45472           A friend said I should read about death.
# 45473  He patiently awaited as his assistant returned...
# 45474  She was in charge of decorating the 6th grade ...
# 45475        I was so excited to get my hands on a copy.
# 45476  So he drove to the nearest store and bought so...
# 45477   At first he considers drinking a glass of water.
# 45478  He had an issue with where two of his classes ...
# 45479           We wake up very early to beat the crowd.
# 45480            She stayed up late updating her resume.
# 45481         He wanted to change his sleeping schedule.
# 45482  She practiced rigorously to master every movem...
# 45483   I obtained his phone number from a 411 operator.
# 45484  He couldn't believe there was a website that l...
# 45485  But someone pushed him off his bike and stole it.
# 45486  Reggie's sister came over and took him to look...
# 45487                               I decided to not go.
# 45488         He didn't worry, until five more appeared.
# 45489  It was a tradition to pierce all girl babies' ...
# 45490                           Handle ran away one day.
# 45491  Lewis picked her up and the two went to a nice...
# 45492                                His car broke down.
# 45493  Last week, I found an interesting way to make ...
# 45494  She opened the box and immediately plugged it in.
# 45495                      Ted and John had an argument.
#
#                                                sentence3  \
# 0         The doctors told his parents it was unhealthy.
# 1         Carrie would sneak rides on her sister's bike.
# 2      After walking for over a mile, something happe...
# 3      He began yelling about how long his food was t...
# 4      I decided to agree with what she says and list...
# 5      Frank suddenly realized he had a date that night.
# 6              While snorkeling, he saw a cave up ahead.
# 7      It was quite sunny and she forgot her sunglasses.
# 8      Sally flew to visit her mom and her mom's new ...
# 9      Dan pretended that his ball actually landed on...
# 10     During show and tell, Josh's parrot said a bad...
# 11          Hal's dog strained so hard, the leash broke!
# 12         Maxwell told Brenda he needed to talk to her.
# 13          She mixed it up in an attempt to make lunch.
# 14     He told me he had just listened to Beethoven's...
# 15                        They had a lot to catch up on.
# 16              After he won, he went on to using drugs.
# 17     The shopper saw a homeless man shivering in th...
# 18               The six of them sat around a big table.
# 19          He gathered his tools and material supplies.
# 20     They had a great time, but covered in a lot of...
# 21            His dad listened, but didn't say anything.
# 22                They had to make the best tasting one.
# 23     Suddenly, Dan ran into the kitchen and started...
# 24                One day he bought a scratching ticket.
# 25                       I landed on the ground in pain.
# 26     It was delicious and refreshing and she couldn...
# 27       He decided he need to go buy something to cook.
# 28     Virgil bought some fabric and had it reupholst...
# 29     Without telling anyone, she swam out farther, ...
# ...                                                  ...
# 45466       It got in front of him and stopped suddenly.
# 45467   Last night she went to the movies with a friend.
# 45468  He smiled and asked for a phone number at her ...
# 45469  He played  his favorite machine all day, but d...
# 45470                       The concert was to Bon jovi.
# 45471      He was going to hike across the top of Spain.
# 45472                   I read about Death in the bible.
# 45473  She resumed by turning the page of the novel h...
# 45474  She arrived earlier and stayed later than anyo...
# 45475        I ran to every record store to take a look.
# 45476    A week later he noticed that oil was low again.
# 45477  Eventually he decides he wants something warm ...
# 45478  One was on the second story and the one after ...
# 45479                 When we arrive we get our buckets.
# 45480     She arrived at the interview 20 minutes early.
# 45481  He started to exercise an hour before bed ever...
# 45482  At her first big ballet audition, Ann danced w...
# 45483                   I called him and left a message.
# 45484  He signed up for an mturk account and started ...
# 45485      When Ray arrived at school, he saw the thief.
# 45486  Reggie fell in love with a lovely cat named Sara.
# 45487  My grade was high enough that I could skip the...
# 45488         He got to school and the spots had spread.
# 45489  Fran was uneasy with the idea, she wanted to w...
# 45490                                  Trent was so sad.
# 45491  As they walked into the restaurant, they got s...
# 45492                             He took the bus there.
# 45493  I signed up to be a mock juror in Tampa, Florida.
# 45494                  As it turned on, she felt elated.
# 45495  Just as Ted was about to sit down John pulled ...
#
#                                                sentence4  \
# 0      His parents understood and decided to make a c...
# 1      She got nervous on a hill and crashed into a w...
# 2            Morgan decided to propose to her boyfriend.
# 3                         Jane didn't know how to react.
# 4               After I got home, I got a text from her.
# 5      Since Frank was already a bit drunk, he could ...
# 6      He went into the cave, and he was terrified wh...
# 7      Sunny got back into her car and heading toward...
# 8      Although her mom was obviously in love, he was...
# 9      His friends were not paying attention so they ...
# 10     The teacher told Joshua not to bring his bird ...
# 11                He chased the cat for several minutes.
# 12     She thought he'd propose but he wanted to brea...
# 13     Since the place needed meat, she also fried an...
# 14                          I talked to him for an hour.
# 15     Amy listened patiently as Beth told her about ...
# 16                               He blew a lot of money.
# 17     He gave up his place in the line and brought a...
# 18          They took turns deciding which game to play.
# 19                 He labored all day to finish the job.
# 20     They searched for a shower for what felt like ...
# 21     So on Christmas morning, And got a wonderful s...
# 22                          When it was over, Kelly won.
# 23     He had just seen a video of a man trampled by ...
# 24               He won enough money for a down payment.
# 25          Thankfully, a stranger rushed to pick me up.
# 26     She put it on her car roof while fishing for h...
# 27     On the way to the store Todd decided to make h...
# 28     His wife complained again, saying bright green...
# 29       The lifeguard had to help her out of the water.
# ...                                                  ...
# 45466              Tom crashed into the back of the car.
# 45467  She ordered twizzlers but they were the last bag.
# 45468                       She didn't have that either.
# 45469  He eventually had to get something to eat, he ...
# 45470                 My brother and I had a great time.
# 45471              He prepared his supplies and set out.
# 45472            Psalm 23 in the bible deals with death.
# 45473            He was on page 145 of a 940 page novel.
# 45474       The halls were finished and she was pleased.
# 45475                      Finally I was able to get it.
# 45476  He decided that now was the time to sell the car.
# 45477               He brews a nice pot of tea to drink.
# 45478  He would have to rush everyday to try to make ...
# 45479  We head out to the cherry trees and pick for h...
# 45480  The interviewer noted her prompt arrival time ...
# 45481   He would get tired immediately after exercising.
# 45482  However, she was outshone by a dancer filled w...
# 45483          He called me back and arranged a meeting.
# 45484  After a while, Thomas wasn't being honest with...
# 45485  Ray beat up the thief and tried to get his bik...
# 45486  Sara was also lonely and couldn't be around ot...
# 45487          Alas, I didn't read the syllabus correct.
# 45488                               Gary's spots itched.
# 45489  She tried to talk to her mother, who didn't un...
# 45490           He put up missing posters all over town.
# 45491     The two had a lot to talk about during dinner.
# 45492                            The bus broke down too.
# 45493  It was quite interesting, it only lasted 4 hou...
# 45494  For the next three hours Suzy could not stop p...
# 45495  Ted hit his head on a table and had a concussion.
#
#                                                sentence5
# 0                 They got themselves and Dan on a diet.
# 1      The bike frame bent and Carrie got a deep gash...
# 2      Her boyfriend was upset he didn't propose to h...
# 3      Luckily, her coworker intervened and calmed th...
# 4                 She asked if we can hang out tomorrow.
# 5      Frank spent the rest of the night drinking mor...
# 6      Dave swam away as fast as he could, but the sh...
# 7      Sunny found some sunglasses and headed back to...
# 8      Sally went home and wondered about her parents...
# 9      Dan snuck a ball on the green and made his put...
# 10                  When Josh got home, he was grounded.
# 11               Finally Hal lured him back to his side.
# 12     Brenda walked away and now she is the saddest ...
# 13                       She ended up enjoying the meal.
# 14     I left him in the lobby and told him I would s...
# 15     She wanted to go 2nd because she knew hers was...
# 16     Eventually his winnings were revoked after a dui.
# 17     The shopper gave the homeless man a nice warm ...
# 18     They spent six hours playing different board g...
# 19     That night he snuggled with his wife on the bu...
# 20     Finally they found one and decided it was the ...
# 21     He received a puppy with a shiny bow on it's h...
# 22                                      She won a medal.
# 23               His mom made Youtube off limits to Dan.
# 24                  Jeff ended up moving to a new house.
# 25         He took me to the hospital to seek treatment.
# 26     She drove home and the coffee fell off and spi...
# 27     Todd buys everything he needed and goes home a...
# 28           Virgil gave up and threw the recliner away.
# 29                         Jenna had learned her lesson.
# ...                                                  ...
# 45466                                Tom was hurt badly.
# 45467            Kelli was relieved to get the last bag.
# 45468  She did have her mother's number, and that tho...
# 45469  With his back turned, he heard bells and cheer...
# 45470          We all sang Livin on a prayer afterwards.
# 45471         Neil was walking the Camino de Compostela!
# 45472                    I am no longer afraid of death.
# 45473  The assistant stayed with Brad for a few more ...
# 45474  The teachers and students were happy with thei...
# 45475   I was lucky though because it was the last copy.
# 45476  He put an ad in Craigslist and sold the car tw...
# 45477          Fred is happy to have something to drink.
# 45478  Finally he asked the principal to change which...
# 45479  In the end we usually bring home around 20lbs ...
# 45480  Leah gained confidence from the compliment giv...
# 45481  Sam was able to successfully fix his sleeping ...
# 45482  Ann saw that emotion is as important to great ...
# 45483  We ate at Denny's and laughed at the good-old-...
# 45484  Amazon suspended his mturk account for three m...
# 45485  But he was suspended and never saw his bike ag...
# 45486  Reggie adopted Sarah and they live happily tog...
# 45487  I failed the class because the final was worth...
# 45488                Gary was sent home with chickenpox.
# 45489  Fran ultimately decided not to pierce her baby...
# 45490                 Tren got a call his dog was found.
# 45491  At the end of the evening, Lewis leaned in and...
# 45492  He ended up calling his work place that he can...
# 45493            I wish that I could do this every week!
# 45494  She immediately thanked her boyfriend for buyi...
# 45495                    John drove Ted to the hospital.
#
# [45496 rows x 7 columns]

# %%
df = pd.read_csv("../data/storydata.csv")

# %%
max_seqlen=25

def clean_text(string):
    """
    apply lowercasing, inserting space if one of { '.,!? } is found.x
    :param string:
    :return: string
    """
    string = string.lower()
    # insert space before special symbols
    string = re.sub("(['.,!?])", r' \g<1>', string)
    return string

stories = df[['sentence1', 'sentence2', 'sentence3', 'sentence4', 'sentence5']]
answers = df['is_real_ending']
lines = stories.values.tolist()
lines = ([[ ["<PAD>"] * (max_seqlen - len(clean_text(string).split()))
        + clean_text(string).split()
       for string in line] for line in lines])  # extract 'sentence1 - 5'

# 1844       After eating, she falls asleep on the couch.
# 1845       Many Year's later, Han and Leia had a child.
# 1846                Gina pretended it wasn't her phone.
# 1847                  Her anxiety is now under control.
# 1848  Worried, Jan went to the door of the class to ...
# 1849                           Sarah broke her big toe.
# 1850  He realizes he should have moved to New Jersey...
# 1851                                    He was nervous.
# 1852             Her roommate began wearing headphones.
# 1853         While working out, Pete worked up a sweat.
# 1854                       And Clare began feeling hot.
# 1855      After a week, it was time to collect her pay.
# 1856  Gina racked her brain but could find nothing t...
# 1857                  Finally, he realized the problem.
# 1858  The requester was very responsive and decided ...
# 1859                Stacey shared her chips with Kevin.
# 1860                             Glen becomes outraged.
# 1861                       Thankfully the pay was good.
# 1862  Driving, eating, and sleeping were the only re...
# 1863        Gill started acting like Columbo sometimes.
# 1864                  He missed his second to last one.
# 1865  The other man struggled but he was too weak to...
# 1866  A doctor looked at it and told Ivan the bite w...
# 1867                    She fell behind in her studies.
# 1868            She said yes, and they had a good time.
# 1869                          He starts playing a song.
# 1870  They stepped in the cars and put on their seat...
#
#                                RandomFifthSentenceQuiz1  \
# 0                                      He is happy now.
# 1     The brownies are so delicious Laverne eats two...
# 2                 Sarah then decided to move to Europe.
# 3     Gina liked the cookies so much she ate them al...
# 4                   I was very proud of my performance.
# 5           The next day I gave the man twenty dollars.
# 6     Jim took time to decide what he would take a p...
# 7         Ron is immediately fired for insubordination.
# 8     In Vegas, John and Billy competed against eigh...
# 9                                      But she gave up.
# 10    Eventually Trish grudgingly came to accept nat...
# 11                            Corey didn't mind at all.
# 12    Marcy gave her boyfriend a big kiss and said yes.
# 13         Cara told the owner that the food was awful.
# 14                    Tony enjoyed going on the cruise.
# 15                            Ignacio gave up swimming.
# 16                        Danny decided to go to sleep.
# 17                                Mary disliked Pandas.
# 18                    Ellen ended up winning the prize.
# 19    Jesse went to the park with his new friend, Ro...
# 20                Tiffany went in to work the next day.
# 21               But she didn't want her phone anymore.
# 22    Alice called her mother and apologized profusely.
# 23        Ted continues to watch several movies a week.
# 24    She loved it so much she planned a trip for th...
# 25                  Javier decides to get a smartphone.
# 26                          Rachel broke down in tears.
# 27                  Ron started collecting bottle caps.
# 28                                  Sam went on a diet.
# 29                   Larry loved going to the hospital.
# ...                                                 ...
# 1841                    Francisco became an accountant.
# 1842  She hung the pinecones from the trees and wait...
# 1843         This would be our new favorite restaurant.
# 1844                            She was full and happy.
# 1845                              They had no children.
# 1846   Gina's teacher told her she could use her phone.
# 1847              Jill was glad she went to the doctor.
# 1848                 Then she realized it was Saturday.
# 1849                            Sara cried out in pain.
# 1850  Pat thinks about all the time he wasted commut...
# 1851  Todd's knees shook as he skated because he was...
# 1852              Joan was disappointed in her roomate.
# 1853         He showered after he finished working out.
# 1854               She took off her jacket to cool off.
# 1855          Nina bought a new bike with her earnings.
# 1856  Tami wished Gina would shut up, but she just k...
# 1857    Harry quickly fixed the problem for his mother.
# 1858                             I like helping others.
# 1859                   Kevin was very angry with Stacy.
# 1860                 However, turns out to just be gas.
# 1861   If it wasn't such easy work she would have quit.
# 1862  My dad always drove safely and we arrived quic...
